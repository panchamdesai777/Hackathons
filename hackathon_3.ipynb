# %% [markdown]
# <a href="https://colab.research.google.com/github/panchamdesai777/Hackathons/blob/master/hackathon_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Message Polarity Prediction**
#
# All of us receive a ton of messages and emails on a daily basis. Collectively, that is a lot of data which can provide useful insights about the messages that each of us gets. What if you could know whether a certain message has brought you good news or bad news before opening the actual message. In this challenge, we will use Machine Learning to achieve this.
#
# ![alt text](https://www.machinehack.com/wp-content/uploads/2020/04/wk3-banner_2-1536x864.jpg)
#
# ## **Objective**
#
# Given are 53 distinguishing factors that can help in understanding the polarity(Good or Bad) of a message,  your objective as a data scientist is to build a Machine Learning model that can predict whether a text message has brought you good news or bad news.
#
# ## **Dataset Description**
#
# You are provided with the normalized frequencies of 50 words/emojis (Freq_Of_Word_1 to Freq_Of_Word_50) along with 3 engineered features listed below:
#
# * TotalEmojiCharacters: Total number of individual emoji characters normalized. (eg. 🙂 )
# * LengthOFFirstParagraph: The total length of the first paragraph in words normalized
# * StylizedLetters: Total number of letters or characters with a styling element normalized
#
# * Target Variable: IsGoodNews
#
# ## Dataset Overview
#
# * Train data
# ![alt text](https://www.machinehack.com/wp-content/uploads/2020/04/Screenshot-2020-04-28-at-4.29.36-PM-1024x257.png)
#
#
# * Test data
#
#  ![alt text](https://www.machinehack.com/wp-content/uploads/2020/04/Screenshot-2020-04-28-at-4.29.56-PM-1024x279.png)

# %%
#importing all the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.style as style # for styling the graphss
# style.available (to know the available list of styles)
style.use('ggplot') # chosen style
plt.rc('xtick',labelsize=13) # to globally set the tick size
plt.rc('ytick',labelsize=13) # to globally set the tick size
# To print multiple outputs together
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Change column display number during print
pd.set_option('display.max_columns', 500)
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')
# To display float with 2 decimal, avoid scientific printing
pd.options.display.float_format = '{:.2f}'.format
import seaborn as sns
import warnings
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_recall_curve, auc, roc_auc_score, roc_curve, recall_score, classification_report
from sklearn.metrics import roc_auc_score ,mean_squared_error,accuracy_score,classification_report,roc_curve,confusion_matrix,precision_score,f1_score
import itertools
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-05c084c0-24cc-4088-b56d-1571ba7033bf" name="files[]" multiple disabled />
#      <output id="result-05c084c0-24cc-4088-b56d-1571ba7033bf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Train.csv to Train (3).csv

# %%
#Loading The Dataset
import io
#The command written below is generally used to load .csv format file or .data format file.
train_df = pd.read_csv(io.BytesIO(uploaded['Train.csv']))
train_df.head()
# Out:
#    Freq_Of_Word_1  Freq_Of_Word_2  Freq_Of_Word_3  Freq_Of_Word_4  \
# 0           -0.35            2.62            1.25           -0.04
# 1           -0.35           -0.32           -0.56           -0.04
# 2           -0.35           -0.32           -0.56           -0.04
# 3            1.21            2.68            1.29           -0.04
# 4           -0.35           -0.32           -0.56           -0.04
#
#    Freq_Of_Word_5  Freq_Of_Word_6  Freq_Of_Word_7  Freq_Of_Word_8  \
# 0           -0.47           -0.35           -0.30           -0.24
# 1           -0.47           -0.35           -0.30            3.84
# 2           -0.47           -0.35           -0.30           -0.24
# 3            0.22           -0.35           -0.30            0.86
# 4           -0.47           -0.35           -0.30           -0.24
#
#    Freq_Of_Word_9  Freq_Of_Word_10  Freq_Of_Word_11  Freq_Of_Word_12  \
# 0           -0.32            -0.35            -0.32            -0.64
# 1           -0.32            -0.35            -0.32            -0.64
# 2           -0.32            -0.35            -0.32            -0.64
# 3           -0.32             2.37            -0.32             2.03
# 4           -0.32            -0.35            -0.32            -0.64
#
#    Freq_Of_Word_13  Freq_Of_Word_14  Freq_Of_Word_15  Freq_Of_Word_16  \
# 0            -0.31            -0.18            -0.19            -0.33
# 1            -0.31            -0.18            -0.19            -0.33
# 2            -0.31            -0.18            -0.19            -0.33
# 3            -0.31             1.29            -0.19             0.29
# 4            -0.31            -0.18            -0.19            -0.33
#
#    Freq_Of_Word_17  Freq_Of_Word_18  Freq_Of_Word_19  Freq_Of_Word_20  \
# 0            -0.32            -0.36            -0.71             1.07
# 1            -0.32            -0.36            -0.97            -0.19
# 2            -0.32            -0.36            -0.97            -0.19
# 3            -0.32            -0.36             0.13            -0.19
# 4            -0.32            -0.36            -0.97            -0.19
#
#    Freq_Of_Word_21  Freq_Of_Word_22  Freq_Of_Word_23  Freq_Of_Word_24  \
# 0             0.95            -0.13            -0.29             0.76
# 1            -0.71            -0.13            -0.29            -0.20
# 2            -0.71            -0.13            -0.29            -0.20
# 3             3.98            -0.13            -0.29            -0.20
# 4            -0.71            -0.13            -0.29            -0.20
#
#    Freq_Of_Word_25  Freq_Of_Word_26  Freq_Of_Word_27  Freq_Of_Word_28  \
# 0            -0.33            -0.30            -0.21            -0.23
# 1            -0.33            -0.30            -0.21            -0.23
# 2            -0.33            -0.30            -0.21            -0.23
# 3            -0.33            -0.30            -0.21            -0.23
# 4            -0.33            -0.30             0.10            -0.23
#
#    Freq_Of_Word_29  Freq_Of_Word_30  Freq_Of_Word_31  Freq_Of_Word_32  \
# 0            -0.16            -0.23            -0.15             1.31
# 1            -0.16            -0.23            -0.15            -0.15
# 2            -0.16            -0.23            -0.15            -0.15
# 3            -0.16            -0.23            -0.15            -0.15
# 4             0.64            -0.23            -0.15            -0.15
#
#    Freq_Of_Word_33  Freq_Of_Word_34  Freq_Of_Word_35  Freq_Of_Word_36  \
# 0            -0.18            -0.15            -0.24            -0.24
# 1            -0.18            -0.15            -0.24            -0.24
# 2            -0.18            -0.15            -0.24            -0.24
# 3            -0.18            -0.15            -0.24            -0.24
# 4            -0.18            -0.15            -0.24            -0.24
#
#    Freq_Of_Word_37  Freq_Of_Word_38  Freq_Of_Word_39  Freq_Of_Word_40  \
# 0            -0.33            -0.06            -0.18            -0.19
# 1             3.68            -0.06            -0.18            -0.19
# 2            -0.33            -0.06            -0.18            -0.19
# 3            -0.33            -0.06            -0.18            -0.19
# 4            -0.33            -0.06            -0.18            -0.19
#
#    Freq_Of_Word_41  Freq_Of_Word_42  Freq_Of_Word_43  Freq_Of_Word_44  \
# 0            -0.13            -0.17            -0.21            -0.12
# 1            -0.13            -0.17            15.21            -0.12
# 2            -0.13            -0.17            -0.21            -0.12
# 3            -0.13            -0.17            -0.21            -0.12
# 4            -0.13            -0.17            -0.21            -0.12
#
#    Freq_Of_Word_45  Freq_Of_Word_46  Freq_Of_Word_47  Freq_Of_Word_48  \
# 0            -0.32            -0.21            -0.08            -0.12
# 1            -0.32            -0.21            -0.08            -0.12
# 2            -0.32            -0.21            -0.08            -0.12
# 3            -0.32            -0.21            -0.08            -0.12
# 4            -0.32            -0.21            -0.08            -0.12
#
#    Freq_Of_Word_49  Freq_Of_Word_50  TotalEmojiCharacters  \
# 0             0.08             0.16                 -0.03
# 1            -0.15            -0.45                 -0.11
# 2            -0.15            -0.45                 -0.11
# 3            -0.15             0.34                  1.33
# 4            -0.15             0.93                 -0.03
#
#    LengthOFFirstParagraph  StylizedLetters  IsGoodNews
# 0                   -0.05             0.22           1
# 1                   -0.20            -0.41           0
# 2                   -0.19            -0.39           0
# 3                    2.27             0.60           1
# 4                   -0.11            -0.13           0

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-95378344-95a6-4419-8d21-850f35c9e121" name="files[]" multiple disabled />
#      <output id="result-95378344-95a6-4419-8d21-850f35c9e121">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Test.csv to Test (3).csv

# %%
#Loading The Dataset
import io
#The command written below is generally used to load .csv format file or .data format file.
test_df = pd.read_csv(io.BytesIO(uploaded['Test.csv']))
test_df.head()
# Out:
#    Freq_Of_Word_1  Freq_Of_Word_2  Freq_Of_Word_3  Freq_Of_Word_4  \
# 0           -0.35           -0.32           -0.56           -0.04
# 1           -0.35           -0.32           -0.56           -0.04
# 2            0.01           -0.32           -0.35           -0.04
# 3           -0.35           -0.32           -0.56           -0.04
# 4            0.62            0.61           -0.56           -0.04
#
#    Freq_Of_Word_5  Freq_Of_Word_6  Freq_Of_Word_7  Freq_Of_Word_8  \
# 0           -0.47           -0.35           -0.30           -0.24
# 1            0.01           -0.35           -0.30           -0.24
# 2           -0.31            0.03           -0.30           -0.24
# 3           -0.47           -0.35            2.09           -0.24
# 4            0.39            0.69           -0.30            1.13
#
#    Freq_Of_Word_9  Freq_Of_Word_10  Freq_Of_Word_11  Freq_Of_Word_12  \
# 0           -0.32            -0.35            -0.32             0.80
# 1           -0.32             0.57            -0.32            -0.64
# 2            3.43            -0.35            -0.32            -0.26
# 3           -0.32            -0.35            -0.32             0.51
# 4           -0.32            -0.35            -0.32            -0.64
#
#    Freq_Of_Word_13  Freq_Of_Word_14  Freq_Of_Word_15  Freq_Of_Word_16  \
# 0            -0.31            -0.18            -0.19             1.37
# 1            -0.31            -0.18            -0.19            -0.33
# 2            -0.31            -0.18            -0.19            -0.33
# 3            -0.31            -0.18            -0.19            -0.33
# 4            -0.31            -0.18            -0.19            -0.33
#
#    Freq_Of_Word_17  Freq_Of_Word_18  Freq_Of_Word_19  Freq_Of_Word_20  \
# 0            -0.32             2.17            -0.97            -0.19
# 1            -0.32            -0.36            -0.60            -0.19
# 2            -0.32            -0.36            -0.72            -0.19
# 3             1.92            -0.36             1.10            -0.19
# 4            -0.32            -0.36            -0.97            -0.19
#
#    Freq_Of_Word_21  Freq_Of_Word_22  Freq_Of_Word_23  Freq_Of_Word_24  \
# 0             2.74            -0.13            -0.29             2.49
# 1            -0.42            -0.13            -0.29            -0.20
# 2            -0.52            -0.13            -0.29            -0.20
# 3             1.12            -0.13            -0.29            -0.20
# 4            -0.71            -0.13            -0.29            -0.20
#
#    Freq_Of_Word_25  Freq_Of_Word_26  Freq_Of_Word_27  Freq_Of_Word_28  \
# 0            -0.33            -0.30            -0.21            -0.23
# 1             3.95             2.71            -0.21            -0.23
# 2            -0.01             0.48            -0.15            -0.23
# 3            -0.33            -0.30            -0.21            -0.23
# 4             0.01             0.04            -0.21            -0.23
#
#    Freq_Of_Word_29  Freq_Of_Word_30  Freq_Of_Word_31  Freq_Of_Word_32  \
# 0            -0.16            -0.23            -0.15            -0.15
# 1            -0.16            -0.23            -0.15            -0.15
# 2            -0.16            -0.23            -0.15            -0.15
# 3            -0.16            -0.23            -0.15            -0.15
# 4             0.28            -0.23             0.54            -0.15
#
#    Freq_Of_Word_33  Freq_Of_Word_34  Freq_Of_Word_35  Freq_Of_Word_36  \
# 0            -0.18            -0.15            -0.24            -0.24
# 1             0.48            -0.15            -0.24            -0.24
# 2             0.50            -0.15            -0.24            -0.24
# 3            -0.18            -0.15            -0.24            -0.24
# 4            -0.18            -0.15             0.44             0.49
#
#    Freq_Of_Word_37  Freq_Of_Word_38  Freq_Of_Word_39  Freq_Of_Word_40  \
# 0            -0.33            -0.06            -0.18            -0.19
# 1             2.64            -0.06            -0.18            -0.19
# 2             0.17            -0.06            -0.18            -0.19
# 3            -0.33            -0.06            -0.18            -0.19
# 4            -0.33            -0.06            -0.18            -0.19
#
#    Freq_Of_Word_41  Freq_Of_Word_42  Freq_Of_Word_43  Freq_Of_Word_44  \
# 0            -0.13            -0.17            -0.21            -0.12
# 1             8.11             0.21            -0.21             0.29
# 2            -0.13            -0.17            -0.21            -0.12
# 3            -0.13            -0.17            -0.21            -0.12
# 4            -0.13            -0.17             1.09            -0.12
#
#    Freq_Of_Word_45  Freq_Of_Word_46  Freq_Of_Word_47  Freq_Of_Word_48  \
# 0            -0.32             1.28            -0.08            -0.12
# 1            -0.32            -0.21            -0.08            -0.12
# 2            -0.32            -0.21            -0.08            -0.12
# 3            -0.32            -0.21            -0.08            -0.12
# 4            -0.32            -0.21            -0.08            -0.12
#
#    Freq_Of_Word_49  Freq_Of_Word_50  TotalEmojiCharacters  \
# 0            -0.15            -0.45                 -0.00
# 1             1.07             1.15                 -0.05
# 2             0.12             0.07                 -0.05
# 3             0.07             0.30                 -0.05
# 4            -0.15            -0.45                 -0.11
#
#    LengthOFFirstParagraph  StylizedLetters
# 0                   -0.01            -0.28
# 1                   -0.15             0.05
# 2                   -0.06             0.32
# 3                    0.01            -0.20
# 4                   -0.19            -0.31

# %%
train, test = train_df,test_df
target = train['IsGoodNews']
features = [c for c in train.columns if c not in ['IsGoodNews']]

# %%
import datetime
import time
from sklearn.model_selection import *
from sklearn.metrics import *
def custom_metric(y_true, y_pred):
    return f'F1_score: {f1_score(y_true, np.round(y_pred))}'
N_FOLDS = 5

training_start_time = time.time()

max_iter = N_FOLDS
folds = StratifiedKFold(n_splits = max_iter)
oofs = np.zeros(len(train))
preds_test = np.zeros(len(test))

feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(train, target.values)):
    
    print(f'\n---- Fold {fold_} -----\n')
    
    fold_start_time = time.time()
    
    X_trn, y_trn = train.iloc[trn_idx][features], target.iloc[trn_idx]
    X_val, y_val = train.iloc[val_idx][features], target.iloc[val_idx]
    X_test = test[features]
    
    print(X_trn.shape)
    
    clf = LGBMClassifier(n_estimators = 4000, learning_rate = 0.01, num_leaves=200, max_depth=4, colsample_by_tree =2, reg_alpha=0.5, reg_lambda=0.5, 
                        bagging_freq=1, bagging_fraction=0.8, max_bin=50,random_state=9)
    _ = clf.fit(X_trn, y_trn, eval_set = [(X_trn, y_trn), (X_val, y_val)], eval_metric = 'f1', verbose = 100, early_stopping_rounds = 200)
    
    oofs[val_idx] = clf.predict_proba(X_val)[:, 1]
    current_test_pred = clf.predict_proba(X_test)[:, 1]
    preds_test += clf.predict_proba(X_test)[:, 1]/max_iter
    
    print(f'\n Fold {custom_metric(y_val, oofs[val_idx])}')

    fold_importance_df = pd.DataFrame({'feature': X_trn.columns.tolist(), 'importance': clf.feature_importances_})
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    fold_end_time = time.time()
    total_fold_time = int(fold_end_time - fold_start_time)
    
    print(f"\n->-> Fold ran for {(total_fold_time)//60} minutes {(total_fold_time)%60} seconds")
    

print(f'\nOOF val score: {custom_metric(target, oofs)}')
training_end_time = time.time()
total_training_time = int(training_end_time - training_start_time)

print(f'\n->-> Total training time: {(total_training_time)//60} minutes {(total_training_time)%60} seconds')
# Out:
# ---- Fold 0 -----
#
# (757, 53)
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.36646	valid_1's binary_logloss: 0.37587
# [200]	training's binary_logloss: 0.254585	valid_1's binary_logloss: 0.266325
# [300]	training's binary_logloss: 0.202191	valid_1's binary_logloss: 0.220946
# [400]	training's binary_logloss: 0.172192	valid_1's binary_logloss: 0.199899
# [500]	training's binary_logloss: 0.149921	valid_1's binary_logloss: 0.188991
# [600]	training's binary_logloss: 0.13262	valid_1's binary_logloss: 0.182138
# [700]	training's binary_logloss: 0.118942	valid_1's binary_logloss: 0.176486
# [800]	training's binary_logloss: 0.107052	valid_1's binary_logloss: 0.172644
# [900]	training's binary_logloss: 0.0975208	valid_1's binary_logloss: 0.170979
# [1000]	training's binary_logloss: 0.0892785	valid_1's binary_logloss: 0.169613
# [1100]	training's binary_logloss: 0.0822582	valid_1's binary_logloss: 0.168017
# [1200]	training's binary_logloss: 0.0762184	valid_1's binary_logloss: 0.167314
# [1300]	training's binary_logloss: 0.0707972	valid_1's binary_logloss: 0.167629
# [1400]	training's binary_logloss: 0.066323	valid_1's binary_logloss: 0.166222
# [1500]	training's binary_logloss: 0.0621955	valid_1's binary_logloss: 0.165732
# [1600]	training's binary_logloss: 0.0584372	valid_1's binary_logloss: 0.165329
# [1700]	training's binary_logloss: 0.0553132	valid_1's binary_logloss: 0.165705
# [1800]	training's binary_logloss: 0.0525795	valid_1's binary_logloss: 0.166245
# Early stopping, best iteration is:
# [1606]	training's binary_logloss: 0.0582557	valid_1's binary_logloss: 0.165261
#
#  Fold F1_score: 0.8918918918918919
#
# ->-> Fold ran for 0 minutes 1 seconds
#
# ---- Fold 1 -----
#
# (757, 53)
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.361155	valid_1's binary_logloss: 0.380088
# [200]	training's binary_logloss: 0.247451	valid_1's binary_logloss: 0.278296
# [300]	training's binary_logloss: 0.196157	valid_1's binary_logloss: 0.23609
# [400]	training's binary_logloss: 0.167083	valid_1's binary_logloss: 0.214433
# [500]	training's binary_logloss: 0.146045	valid_1's binary_logloss: 0.202127
# [600]	training's binary_logloss: 0.129555	valid_1's binary_logloss: 0.193126
# [700]	training's binary_logloss: 0.114901	valid_1's binary_logloss: 0.184766
# [800]	training's binary_logloss: 0.103261	valid_1's binary_logloss: 0.178382
# [900]	training's binary_logloss: 0.0935395	valid_1's binary_logloss: 0.174793
# [1000]	training's binary_logloss: 0.0858172	valid_1's binary_logloss: 0.170685
# [1100]	training's binary_logloss: 0.0790199	valid_1's binary_logloss: 0.169665
# [1200]	training's binary_logloss: 0.0735551	valid_1's binary_logloss: 0.168557
# [1300]	training's binary_logloss: 0.0686173	valid_1's binary_logloss: 0.167246
# [1400]	training's binary_logloss: 0.0642661	valid_1's binary_logloss: 0.166589
# [1500]	training's binary_logloss: 0.0605012	valid_1's binary_logloss: 0.165914
# [1600]	training's binary_logloss: 0.0570329	valid_1's binary_logloss: 0.165159
# [1700]	training's binary_logloss: 0.0540549	valid_1's binary_logloss: 0.165483
# [1800]	training's binary_logloss: 0.0514324	valid_1's binary_logloss: 0.16603
# Early stopping, best iteration is:
# [1627]	training's binary_logloss: 0.0562577	valid_1's binary_logloss: 0.164984
#
#  Fold F1_score: 0.9251700680272108
#
# ->-> Fold ran for 0 minutes 1 seconds
#
# ---- Fold 2 -----
#
# (758, 53)
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.361358	valid_1's binary_logloss: 0.382017
# [200]	training's binary_logloss: 0.250406	valid_1's binary_logloss: 0.273182
# [300]	training's binary_logloss: 0.200807	valid_1's binary_logloss: 0.22679
# [400]	training's binary_logloss: 0.170872	valid_1's binary_logloss: 0.200748
# [500]	training's binary_logloss: 0.148763	valid_1's binary_logloss: 0.184062
# [600]	training's binary_logloss: 0.131255	valid_1's binary_logloss: 0.173919
# [700]	training's binary_logloss: 0.11691	valid_1's binary_logloss: 0.164127
# [800]	training's binary_logloss: 0.104963	valid_1's binary_logloss: 0.158669
# [900]	training's binary_logloss: 0.0954784	valid_1's binary_logloss: 0.154175
# [1000]	training's binary_logloss: 0.0877153	valid_1's binary_logloss: 0.151634
# [1100]	training's binary_logloss: 0.0806215	valid_1's binary_logloss: 0.149266
# [1200]	training's binary_logloss: 0.0742083	valid_1's binary_logloss: 0.148289
# [1300]	training's binary_logloss: 0.0689053	valid_1's binary_logloss: 0.146477
# [1400]	training's binary_logloss: 0.0644633	valid_1's binary_logloss: 0.14576
# [1500]	training's binary_logloss: 0.0605895	valid_1's binary_logloss: 0.145206
# [1600]	training's binary_logloss: 0.0568594	valid_1's binary_logloss: 0.145461
# [1700]	training's binary_logloss: 0.0536185	valid_1's binary_logloss: 0.144958
# Early stopping, best iteration is:
# [1529]	training's binary_logloss: 0.0594324	valid_1's binary_logloss: 0.144715
#
#  Fold F1_score: 0.921985815602837
#
# ->-> Fold ran for 0 minutes 1 seconds
#
# ---- Fold 3 -----
#
# (758, 53)
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.361301	valid_1's binary_logloss: 0.392777
# [200]	training's binary_logloss: 0.246249	valid_1's binary_logloss: 0.29413
# [300]	training's binary_logloss: 0.193694	valid_1's binary_logloss: 0.255715
# [400]	training's binary_logloss: 0.164152	valid_1's binary_logloss: 0.239426
# [500]	training's binary_logloss: 0.143085	valid_1's binary_logloss: 0.227527
# [600]	training's binary_logloss: 0.127026	valid_1's binary_logloss: 0.218545
# [700]	training's binary_logloss: 0.113235	valid_1's binary_logloss: 0.209631
# [800]	training's binary_logloss: 0.102073	valid_1's binary_logloss: 0.202826
# [900]	training's binary_logloss: 0.0920949	valid_1's binary_logloss: 0.197199
# [1000]	training's binary_logloss: 0.0837567	valid_1's binary_logloss: 0.192542
# [1100]	training's binary_logloss: 0.0766774	valid_1's binary_logloss: 0.188894
# [1200]	training's binary_logloss: 0.0707128	valid_1's binary_logloss: 0.185784
# [1300]	training's binary_logloss: 0.0651902	valid_1's binary_logloss: 0.182949
# [1400]	training's binary_logloss: 0.0605357	valid_1's binary_logloss: 0.180326
# [1500]	training's binary_logloss: 0.0566322	valid_1's binary_logloss: 0.178966
# [1600]	training's binary_logloss: 0.0528859	valid_1's binary_logloss: 0.177058
# [1700]	training's binary_logloss: 0.0495959	valid_1's binary_logloss: 0.176101
# [1800]	training's binary_logloss: 0.0468462	valid_1's binary_logloss: 0.174894
# [1900]	training's binary_logloss: 0.044515	valid_1's binary_logloss: 0.174151
# [2000]	training's binary_logloss: 0.0422409	valid_1's binary_logloss: 0.173719
# [2100]	training's binary_logloss: 0.0403044	valid_1's binary_logloss: 0.17377
# [2200]	training's binary_logloss: 0.0385599	valid_1's binary_logloss: 0.173967
# Early stopping, best iteration is:
# [2046]	training's binary_logloss: 0.0413658	valid_1's binary_logloss: 0.173548
#
#  Fold F1_score: 0.9166666666666666
#
# ->-> Fold ran for 0 minutes 1 seconds
#
# ---- Fold 4 -----
#
# (758, 53)
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.361989	valid_1's binary_logloss: 0.381149
# [200]	training's binary_logloss: 0.249748	valid_1's binary_logloss: 0.284483
# [300]	training's binary_logloss: 0.196339	valid_1's binary_logloss: 0.244537
# [400]	training's binary_logloss: 0.16547	valid_1's binary_logloss: 0.225725
# [500]	training's binary_logloss: 0.142983	valid_1's binary_logloss: 0.216726
# [600]	training's binary_logloss: 0.125792	valid_1's binary_logloss: 0.209836
# [700]	training's binary_logloss: 0.111503	valid_1's binary_logloss: 0.205501
# [800]	training's binary_logloss: 0.10023	valid_1's binary_logloss: 0.202608
# [900]	training's binary_logloss: 0.0904857	valid_1's binary_logloss: 0.200908
# [1000]	training's binary_logloss: 0.082236	valid_1's binary_logloss: 0.19917
# [1100]	training's binary_logloss: 0.0756828	valid_1's binary_logloss: 0.198642
# [1200]	training's binary_logloss: 0.0699038	valid_1's binary_logloss: 0.197929
# [1300]	training's binary_logloss: 0.0649044	valid_1's binary_logloss: 0.198552
# Early stopping, best iteration is:
# [1159]	training's binary_logloss: 0.0722427	valid_1's binary_logloss: 0.197532
#
#  Fold F1_score: 0.8918918918918919
#
# ->-> Fold ran for 0 minutes 0 seconds
#
# OOF val score: F1_score: 0.9093406593406593
#
# ->-> Total training time: 0 minutes 5 seconds

# %%
feature_importance_df[feature_importance_df['importance']<=0]
# Out:
#             feature  importance
# 3    Freq_Of_Word_4           0
# 21  Freq_Of_Word_22           0
# 29  Freq_Of_Word_30           0
# 30  Freq_Of_Word_31           0
# 31  Freq_Of_Word_32           0
# 33  Freq_Of_Word_34           0
# 37  Freq_Of_Word_38           0
# 40  Freq_Of_Word_41           0
# 42  Freq_Of_Word_43           0
# 46  Freq_Of_Word_47           0
# 47  Freq_Of_Word_48           0
# 3    Freq_Of_Word_4           0
# 21  Freq_Of_Word_22           0
# 30  Freq_Of_Word_31           0
# 31  Freq_Of_Word_32           0
# 33  Freq_Of_Word_34           0
# 37  Freq_Of_Word_38           0
# 40  Freq_Of_Word_41           0
# 42  Freq_Of_Word_43           0
# 46  Freq_Of_Word_47           0
# 47  Freq_Of_Word_48           0
# 3    Freq_Of_Word_4           0
# 21  Freq_Of_Word_22           0
# 30  Freq_Of_Word_31           0
# 31  Freq_Of_Word_32           0
# 33  Freq_Of_Word_34           0
# 37  Freq_Of_Word_38           0
# 40  Freq_Of_Word_41           0
# 46  Freq_Of_Word_47           0
# 47  Freq_Of_Word_48           0
# 3    Freq_Of_Word_4           0
# 30  Freq_Of_Word_31           0
# 31  Freq_Of_Word_32           0
# 33  Freq_Of_Word_34           0
# 37  Freq_Of_Word_38           0
# 40  Freq_Of_Word_41           0
# 43  Freq_Of_Word_44           0
# 46  Freq_Of_Word_47           0
# 47  Freq_Of_Word_48           0
# 3    Freq_Of_Word_4           0
# 14  Freq_Of_Word_15           0
# 21  Freq_Of_Word_22           0
# 29  Freq_Of_Word_30           0
# 30  Freq_Of_Word_31           0
# 31  Freq_Of_Word_32           0
# 33  Freq_Of_Word_34           0
# 37  Freq_Of_Word_38           0
# 40  Freq_Of_Word_41           0
# 42  Freq_Of_Word_43           0
# 46  Freq_Of_Word_47           0
# 47  Freq_Of_Word_48           0

# %%
test_df['IsGoodNews']=voting_clf_soft_2.predict(test_df)

# %%
A=test_df['IsGoodNews']
A=pd.DataFrame(A)
A
A.to_excel('new_model.xlsx')
# Out:
#      IsGoodNews
# 0             1
# 1             0
# 2             0
# 3             1
# 4             0
# ..          ...
# 522           0
# 523           1
# 524           0
# 525           0
# 526           0
#
# [527 rows x 1 columns]

# %%
from google.colab import files
files.download('new_model.xlsx')
