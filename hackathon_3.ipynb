# %% [markdown]
# <a href="https://colab.research.google.com/github/panchamdesai777/Hackathons/blob/master/hackathon_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Message Polarity Prediction**
#
# All of us receive a ton of messages and emails on a daily basis. Collectively, that is a lot of data which can provide useful insights about the messages that each of us gets. What if you could know whether a certain message has brought you good news or bad news before opening the actual message. In this challenge, we will use Machine Learning to achieve this.
#
# ![alt text](https://www.machinehack.com/wp-content/uploads/2020/04/wk3-banner_2-1536x864.jpg)
#
# ## **Objective**
#
# Given are 53 distinguishing factors that can help in understanding the polarity(Good or Bad) of a message,  your objective as a data scientist is to build a Machine Learning model that can predict whether a text message has brought you good news or bad news.
#
# ## **Dataset Description**
#
# You are provided with the normalized frequencies of 50 words/emojis (Freq_Of_Word_1 to Freq_Of_Word_50) along with 3 engineered features listed below:
#
# * TotalEmojiCharacters: Total number of individual emoji characters normalized. (eg. 🙂 )
# * LengthOFFirstParagraph: The total length of the first paragraph in words normalized
# * StylizedLetters: Total number of letters or characters with a styling element normalized
#
# * Target Variable: IsGoodNews
#
# ## Dataset Overview
#
# * Train data
# ![alt text](https://www.machinehack.com/wp-content/uploads/2020/04/Screenshot-2020-04-28-at-4.29.36-PM-1024x257.png)
#
#
# * Test data
#
#  ![alt text](https://www.machinehack.com/wp-content/uploads/2020/04/Screenshot-2020-04-28-at-4.29.56-PM-1024x279.png)

# %%
#importing all the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.style as style # for styling the graphss
# style.available (to know the available list of styles)
style.use('ggplot') # chosen style
plt.rc('xtick',labelsize=13) # to globally set the tick size
plt.rc('ytick',labelsize=13) # to globally set the tick size
# To print multiple outputs together
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Change column display number during print
pd.set_option('display.max_columns', 500)
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')
# To display float with 2 decimal, avoid scientific printing
pd.options.display.float_format = '{:.2f}'.format
import seaborn as sns
import warnings
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_recall_curve, auc, roc_auc_score, roc_curve, recall_score, classification_report
from sklearn.metrics import roc_auc_score ,mean_squared_error,accuracy_score,classification_report,roc_curve,confusion_matrix,precision_score,f1_score
import itertools
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9626d0b2-a390-4401-974b-3043a9fc04da" name="files[]" multiple disabled />
#      <output id="result-9626d0b2-a390-4401-974b-3043a9fc04da">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Train.csv to Train (2).csv

# %%
#Loading The Dataset
import io
#The command written below is generally used to load .csv format file or .data format file.
train_df = pd.read_csv(io.BytesIO(uploaded['Train.csv']))
train_df.head()
# Out:
#    Freq_Of_Word_1  Freq_Of_Word_2  Freq_Of_Word_3  Freq_Of_Word_4  \
# 0           -0.35            2.62            1.25           -0.04
# 1           -0.35           -0.32           -0.56           -0.04
# 2           -0.35           -0.32           -0.56           -0.04
# 3            1.21            2.68            1.29           -0.04
# 4           -0.35           -0.32           -0.56           -0.04
#
#    Freq_Of_Word_5  Freq_Of_Word_6  Freq_Of_Word_7  Freq_Of_Word_8  \
# 0           -0.47           -0.35           -0.30           -0.24
# 1           -0.47           -0.35           -0.30            3.84
# 2           -0.47           -0.35           -0.30           -0.24
# 3            0.22           -0.35           -0.30            0.86
# 4           -0.47           -0.35           -0.30           -0.24
#
#    Freq_Of_Word_9  Freq_Of_Word_10  Freq_Of_Word_11  Freq_Of_Word_12  \
# 0           -0.32            -0.35            -0.32            -0.64
# 1           -0.32            -0.35            -0.32            -0.64
# 2           -0.32            -0.35            -0.32            -0.64
# 3           -0.32             2.37            -0.32             2.03
# 4           -0.32            -0.35            -0.32            -0.64
#
#    Freq_Of_Word_13  Freq_Of_Word_14  Freq_Of_Word_15  Freq_Of_Word_16  \
# 0            -0.31            -0.18            -0.19            -0.33
# 1            -0.31            -0.18            -0.19            -0.33
# 2            -0.31            -0.18            -0.19            -0.33
# 3            -0.31             1.29            -0.19             0.29
# 4            -0.31            -0.18            -0.19            -0.33
#
#    Freq_Of_Word_17  Freq_Of_Word_18  Freq_Of_Word_19  Freq_Of_Word_20  \
# 0            -0.32            -0.36            -0.71             1.07
# 1            -0.32            -0.36            -0.97            -0.19
# 2            -0.32            -0.36            -0.97            -0.19
# 3            -0.32            -0.36             0.13            -0.19
# 4            -0.32            -0.36            -0.97            -0.19
#
#    Freq_Of_Word_21  Freq_Of_Word_22  Freq_Of_Word_23  Freq_Of_Word_24  \
# 0             0.95            -0.13            -0.29             0.76
# 1            -0.71            -0.13            -0.29            -0.20
# 2            -0.71            -0.13            -0.29            -0.20
# 3             3.98            -0.13            -0.29            -0.20
# 4            -0.71            -0.13            -0.29            -0.20
#
#    Freq_Of_Word_25  Freq_Of_Word_26  Freq_Of_Word_27  Freq_Of_Word_28  \
# 0            -0.33            -0.30            -0.21            -0.23
# 1            -0.33            -0.30            -0.21            -0.23
# 2            -0.33            -0.30            -0.21            -0.23
# 3            -0.33            -0.30            -0.21            -0.23
# 4            -0.33            -0.30             0.10            -0.23
#
#    Freq_Of_Word_29  Freq_Of_Word_30  Freq_Of_Word_31  Freq_Of_Word_32  \
# 0            -0.16            -0.23            -0.15             1.31
# 1            -0.16            -0.23            -0.15            -0.15
# 2            -0.16            -0.23            -0.15            -0.15
# 3            -0.16            -0.23            -0.15            -0.15
# 4             0.64            -0.23            -0.15            -0.15
#
#    Freq_Of_Word_33  Freq_Of_Word_34  Freq_Of_Word_35  Freq_Of_Word_36  \
# 0            -0.18            -0.15            -0.24            -0.24
# 1            -0.18            -0.15            -0.24            -0.24
# 2            -0.18            -0.15            -0.24            -0.24
# 3            -0.18            -0.15            -0.24            -0.24
# 4            -0.18            -0.15            -0.24            -0.24
#
#    Freq_Of_Word_37  Freq_Of_Word_38  Freq_Of_Word_39  Freq_Of_Word_40  \
# 0            -0.33            -0.06            -0.18            -0.19
# 1             3.68            -0.06            -0.18            -0.19
# 2            -0.33            -0.06            -0.18            -0.19
# 3            -0.33            -0.06            -0.18            -0.19
# 4            -0.33            -0.06            -0.18            -0.19
#
#    Freq_Of_Word_41  Freq_Of_Word_42  Freq_Of_Word_43  Freq_Of_Word_44  \
# 0            -0.13            -0.17            -0.21            -0.12
# 1            -0.13            -0.17            15.21            -0.12
# 2            -0.13            -0.17            -0.21            -0.12
# 3            -0.13            -0.17            -0.21            -0.12
# 4            -0.13            -0.17            -0.21            -0.12
#
#    Freq_Of_Word_45  Freq_Of_Word_46  Freq_Of_Word_47  Freq_Of_Word_48  \
# 0            -0.32            -0.21            -0.08            -0.12
# 1            -0.32            -0.21            -0.08            -0.12
# 2            -0.32            -0.21            -0.08            -0.12
# 3            -0.32            -0.21            -0.08            -0.12
# 4            -0.32            -0.21            -0.08            -0.12
#
#    Freq_Of_Word_49  Freq_Of_Word_50  TotalEmojiCharacters  \
# 0             0.08             0.16                 -0.03
# 1            -0.15            -0.45                 -0.11
# 2            -0.15            -0.45                 -0.11
# 3            -0.15             0.34                  1.33
# 4            -0.15             0.93                 -0.03
#
#    LengthOFFirstParagraph  StylizedLetters  IsGoodNews
# 0                   -0.05             0.22           1
# 1                   -0.20            -0.41           0
# 2                   -0.19            -0.39           0
# 3                    2.27             0.60           1
# 4                   -0.11            -0.13           0

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6feb8a13-0f22-4b7f-8858-c8e4fb639d7e" name="files[]" multiple disabled />
#      <output id="result-6feb8a13-0f22-4b7f-8858-c8e4fb639d7e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Test.csv to Test (2).csv

# %%
#Loading The Dataset
import io
#The command written below is generally used to load .csv format file or .data format file.
test_df = pd.read_csv(io.BytesIO(uploaded['Test.csv']))
test_df.head()
# Out:
#    Freq_Of_Word_1  Freq_Of_Word_2  Freq_Of_Word_3  Freq_Of_Word_4  \
# 0           -0.35           -0.32           -0.56           -0.04
# 1           -0.35           -0.32           -0.56           -0.04
# 2            0.01           -0.32           -0.35           -0.04
# 3           -0.35           -0.32           -0.56           -0.04
# 4            0.62            0.61           -0.56           -0.04
#
#    Freq_Of_Word_5  Freq_Of_Word_6  Freq_Of_Word_7  Freq_Of_Word_8  \
# 0           -0.47           -0.35           -0.30           -0.24
# 1            0.01           -0.35           -0.30           -0.24
# 2           -0.31            0.03           -0.30           -0.24
# 3           -0.47           -0.35            2.09           -0.24
# 4            0.39            0.69           -0.30            1.13
#
#    Freq_Of_Word_9  Freq_Of_Word_10  Freq_Of_Word_11  Freq_Of_Word_12  \
# 0           -0.32            -0.35            -0.32             0.80
# 1           -0.32             0.57            -0.32            -0.64
# 2            3.43            -0.35            -0.32            -0.26
# 3           -0.32            -0.35            -0.32             0.51
# 4           -0.32            -0.35            -0.32            -0.64
#
#    Freq_Of_Word_13  Freq_Of_Word_14  Freq_Of_Word_15  Freq_Of_Word_16  \
# 0            -0.31            -0.18            -0.19             1.37
# 1            -0.31            -0.18            -0.19            -0.33
# 2            -0.31            -0.18            -0.19            -0.33
# 3            -0.31            -0.18            -0.19            -0.33
# 4            -0.31            -0.18            -0.19            -0.33
#
#    Freq_Of_Word_17  Freq_Of_Word_18  Freq_Of_Word_19  Freq_Of_Word_20  \
# 0            -0.32             2.17            -0.97            -0.19
# 1            -0.32            -0.36            -0.60            -0.19
# 2            -0.32            -0.36            -0.72            -0.19
# 3             1.92            -0.36             1.10            -0.19
# 4            -0.32            -0.36            -0.97            -0.19
#
#    Freq_Of_Word_21  Freq_Of_Word_22  Freq_Of_Word_23  Freq_Of_Word_24  \
# 0             2.74            -0.13            -0.29             2.49
# 1            -0.42            -0.13            -0.29            -0.20
# 2            -0.52            -0.13            -0.29            -0.20
# 3             1.12            -0.13            -0.29            -0.20
# 4            -0.71            -0.13            -0.29            -0.20
#
#    Freq_Of_Word_25  Freq_Of_Word_26  Freq_Of_Word_27  Freq_Of_Word_28  \
# 0            -0.33            -0.30            -0.21            -0.23
# 1             3.95             2.71            -0.21            -0.23
# 2            -0.01             0.48            -0.15            -0.23
# 3            -0.33            -0.30            -0.21            -0.23
# 4             0.01             0.04            -0.21            -0.23
#
#    Freq_Of_Word_29  Freq_Of_Word_30  Freq_Of_Word_31  Freq_Of_Word_32  \
# 0            -0.16            -0.23            -0.15            -0.15
# 1            -0.16            -0.23            -0.15            -0.15
# 2            -0.16            -0.23            -0.15            -0.15
# 3            -0.16            -0.23            -0.15            -0.15
# 4             0.28            -0.23             0.54            -0.15
#
#    Freq_Of_Word_33  Freq_Of_Word_34  Freq_Of_Word_35  Freq_Of_Word_36  \
# 0            -0.18            -0.15            -0.24            -0.24
# 1             0.48            -0.15            -0.24            -0.24
# 2             0.50            -0.15            -0.24            -0.24
# 3            -0.18            -0.15            -0.24            -0.24
# 4            -0.18            -0.15             0.44             0.49
#
#    Freq_Of_Word_37  Freq_Of_Word_38  Freq_Of_Word_39  Freq_Of_Word_40  \
# 0            -0.33            -0.06            -0.18            -0.19
# 1             2.64            -0.06            -0.18            -0.19
# 2             0.17            -0.06            -0.18            -0.19
# 3            -0.33            -0.06            -0.18            -0.19
# 4            -0.33            -0.06            -0.18            -0.19
#
#    Freq_Of_Word_41  Freq_Of_Word_42  Freq_Of_Word_43  Freq_Of_Word_44  \
# 0            -0.13            -0.17            -0.21            -0.12
# 1             8.11             0.21            -0.21             0.29
# 2            -0.13            -0.17            -0.21            -0.12
# 3            -0.13            -0.17            -0.21            -0.12
# 4            -0.13            -0.17             1.09            -0.12
#
#    Freq_Of_Word_45  Freq_Of_Word_46  Freq_Of_Word_47  Freq_Of_Word_48  \
# 0            -0.32             1.28            -0.08            -0.12
# 1            -0.32            -0.21            -0.08            -0.12
# 2            -0.32            -0.21            -0.08            -0.12
# 3            -0.32            -0.21            -0.08            -0.12
# 4            -0.32            -0.21            -0.08            -0.12
#
#    Freq_Of_Word_49  Freq_Of_Word_50  TotalEmojiCharacters  \
# 0            -0.15            -0.45                 -0.00
# 1             1.07             1.15                 -0.05
# 2             0.12             0.07                 -0.05
# 3             0.07             0.30                 -0.05
# 4            -0.15            -0.45                 -0.11
#
#    LengthOFFirstParagraph  StylizedLetters
# 0                   -0.01            -0.28
# 1                   -0.15             0.05
# 2                   -0.06             0.32
# 3                    0.01            -0.20
# 4                   -0.19            -0.31

# %%
train, test = train_df,test_df
target = train['IsGoodNews']
features = [c for c in train.columns if c not in ['IsGoodNews']]

# %%
import datetime
import time
from sklearn.model_selection import *
from sklearn.metrics import *
def custom_metric(y_true, y_pred):
    return f'F1_score: {f1_score(y_true, np.round(y_pred))}'
N_FOLDS = 5

training_start_time = time.time()

max_iter = N_FOLDS
folds = StratifiedKFold(n_splits = max_iter)
oofs = np.zeros(len(train))
preds_test = np.zeros(len(test))

feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(train, target.values)):
    
    print(f'\n---- Fold {fold_} -----\n')
    
    fold_start_time = time.time()
    
    X_trn, y_trn = train.iloc[trn_idx][features], target.iloc[trn_idx]
    X_val, y_val = train.iloc[val_idx][features], target.iloc[val_idx]
    X_test = test[features]
    
    print(X_trn.shape)
    
    clf = LGBMClassifier(n_estimators = 4000, learning_rate = 0.01, num_leaves=200, colsample_by_tree =3, reg_alpha=0.5, reg_lambda=0.5, 
                        bagging_freq=1, bagging_fraction=0.8, max_bin=50,random_state=9)
    _ = clf.fit(X_trn, y_trn, eval_set = [(X_trn, y_trn), (X_val, y_val)], eval_metric = 'f1', verbose = 100, early_stopping_rounds = 200)
    
    oofs[val_idx] = clf.predict_proba(X_val)[:, 1]
    current_test_pred = clf.predict_proba(X_test)[:, 1]
    preds_test += clf.predict_proba(X_test)[:, 1]/max_iter
    
    print(f'\n Fold {custom_metric(y_val, oofs[val_idx])}')

    fold_importance_df = pd.DataFrame({'feature': X_trn.columns.tolist(), 'importance': clf.feature_importances_})
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    fold_end_time = time.time()
    total_fold_time = int(fold_end_time - fold_start_time)
    
    print(f"\n->-> Fold ran for {(total_fold_time)//60} minutes {(total_fold_time)%60} seconds")
    

print(f'\nOOF val score: {custom_metric(target, oofs)}')
training_end_time = time.time()
total_training_time = int(training_end_time - training_start_time)

print(f'\n->-> Total training time: {(total_training_time)//60} minutes {(total_training_time)%60} seconds')
# Out:
# ---- Fold 0 -----
#
# (757, 53)
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.34926	valid_1's binary_logloss: 0.370118
# [200]	training's binary_logloss: 0.225559	valid_1's binary_logloss: 0.257285
# [300]	training's binary_logloss: 0.164053	valid_1's binary_logloss: 0.209273
# [400]	training's binary_logloss: 0.127549	valid_1's binary_logloss: 0.188804
# [500]	training's binary_logloss: 0.103651	valid_1's binary_logloss: 0.178463
# [600]	training's binary_logloss: 0.0867687	valid_1's binary_logloss: 0.173888
# [700]	training's binary_logloss: 0.0744715	valid_1's binary_logloss: 0.171306
# [800]	training's binary_logloss: 0.0652444	valid_1's binary_logloss: 0.16986
# [900]	training's binary_logloss: 0.0582853	valid_1's binary_logloss: 0.170341
# Early stopping, best iteration is:
# [797]	training's binary_logloss: 0.0655028	valid_1's binary_logloss: 0.169675
#
#  Fold F1_score: 0.8918918918918919
#
# ->-> Fold ran for 0 minutes 0 seconds
#
# ---- Fold 1 -----
#
# (757, 53)
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.349403	valid_1's binary_logloss: 0.377078
# [200]	training's binary_logloss: 0.22462	valid_1's binary_logloss: 0.272774
# [300]	training's binary_logloss: 0.162555	valid_1's binary_logloss: 0.227166
# [400]	training's binary_logloss: 0.12535	valid_1's binary_logloss: 0.205859
# [500]	training's binary_logloss: 0.101511	valid_1's binary_logloss: 0.192853
# [600]	training's binary_logloss: 0.0847589	valid_1's binary_logloss: 0.185422
# [700]	training's binary_logloss: 0.0729519	valid_1's binary_logloss: 0.180403
# [800]	training's binary_logloss: 0.0640508	valid_1's binary_logloss: 0.176076
# [900]	training's binary_logloss: 0.0573781	valid_1's binary_logloss: 0.173356
# [1000]	training's binary_logloss: 0.0518565	valid_1's binary_logloss: 0.171948
# [1100]	training's binary_logloss: 0.047596	valid_1's binary_logloss: 0.171295
# [1200]	training's binary_logloss: 0.0441913	valid_1's binary_logloss: 0.171274
# [1300]	training's binary_logloss: 0.0413688	valid_1's binary_logloss: 0.171335
# Early stopping, best iteration is:
# [1147]	training's binary_logloss: 0.045839	valid_1's binary_logloss: 0.171041
#
#  Fold F1_score: 0.9115646258503401
#
# ->-> Fold ran for 0 minutes 1 seconds
#
# ---- Fold 2 -----
#
# (758, 53)
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.349208	valid_1's binary_logloss: 0.374141
# [200]	training's binary_logloss: 0.226307	valid_1's binary_logloss: 0.257869
# [300]	training's binary_logloss: 0.165303	valid_1's binary_logloss: 0.209177
# [400]	training's binary_logloss: 0.12797	valid_1's binary_logloss: 0.184197
# [500]	training's binary_logloss: 0.103151	valid_1's binary_logloss: 0.170465
# [600]	training's binary_logloss: 0.0856711	valid_1's binary_logloss: 0.165225
# [700]	training's binary_logloss: 0.0730234	valid_1's binary_logloss: 0.16055
# [800]	training's binary_logloss: 0.0637375	valid_1's binary_logloss: 0.158756
# [900]	training's binary_logloss: 0.0567116	valid_1's binary_logloss: 0.157556
# [1000]	training's binary_logloss: 0.0512705	valid_1's binary_logloss: 0.158049
# [1100]	training's binary_logloss: 0.0467478	valid_1's binary_logloss: 0.156645
# [1200]	training's binary_logloss: 0.0430714	valid_1's binary_logloss: 0.158045
# [1300]	training's binary_logloss: 0.0401306	valid_1's binary_logloss: 0.158238
# Early stopping, best iteration is:
# [1102]	training's binary_logloss: 0.0466727	valid_1's binary_logloss: 0.156634
#
#  Fold F1_score: 0.921985815602837
#
# ->-> Fold ran for 0 minutes 1 seconds
#
# ---- Fold 3 -----
#
# (758, 53)
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.347153	valid_1's binary_logloss: 0.381294
# [200]	training's binary_logloss: 0.221634	valid_1's binary_logloss: 0.280407
# [300]	training's binary_logloss: 0.159383	valid_1's binary_logloss: 0.239827
# [400]	training's binary_logloss: 0.121946	valid_1's binary_logloss: 0.222346
# [500]	training's binary_logloss: 0.097761	valid_1's binary_logloss: 0.211417
# [600]	training's binary_logloss: 0.080899	valid_1's binary_logloss: 0.202124
# [700]	training's binary_logloss: 0.0686857	valid_1's binary_logloss: 0.196975
# [800]	training's binary_logloss: 0.0596928	valid_1's binary_logloss: 0.193066
# [900]	training's binary_logloss: 0.0527654	valid_1's binary_logloss: 0.190348
# [1000]	training's binary_logloss: 0.0473702	valid_1's binary_logloss: 0.188602
# [1100]	training's binary_logloss: 0.0432145	valid_1's binary_logloss: 0.188678
# [1200]	training's binary_logloss: 0.0398033	valid_1's binary_logloss: 0.18755
# [1300]	training's binary_logloss: 0.037053	valid_1's binary_logloss: 0.186372
# [1400]	training's binary_logloss: 0.0347617	valid_1's binary_logloss: 0.186306
# [1500]	training's binary_logloss: 0.032808	valid_1's binary_logloss: 0.187002
# Early stopping, best iteration is:
# [1380]	training's binary_logloss: 0.0352087	valid_1's binary_logloss: 0.186105
#
#  Fold F1_score: 0.9027777777777778
#
# ->-> Fold ran for 0 minutes 1 seconds
#
# ---- Fold 4 -----
#
# (758, 53)
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.348474	valid_1's binary_logloss: 0.374061
# [200]	training's binary_logloss: 0.223583	valid_1's binary_logloss: 0.274126
# [300]	training's binary_logloss: 0.159717	valid_1's binary_logloss: 0.23544
# [400]	training's binary_logloss: 0.122564	valid_1's binary_logloss: 0.219124
# [500]	training's binary_logloss: 0.0979167	valid_1's binary_logloss: 0.212778
# [600]	training's binary_logloss: 0.0809959	valid_1's binary_logloss: 0.207489
# [700]	training's binary_logloss: 0.0687282	valid_1's binary_logloss: 0.206552
# [800]	training's binary_logloss: 0.0598254	valid_1's binary_logloss: 0.205524
# [900]	training's binary_logloss: 0.0528915	valid_1's binary_logloss: 0.204
# [1000]	training's binary_logloss: 0.0475094	valid_1's binary_logloss: 0.204399
# [1100]	training's binary_logloss: 0.0433237	valid_1's binary_logloss: 0.204758
# Early stopping, best iteration is:
# [922]	training's binary_logloss: 0.0515874	valid_1's binary_logloss: 0.203323
#
#  Fold F1_score: 0.8933333333333333
#
# ->-> Fold ran for 0 minutes 0 seconds
#
# OOF val score: F1_score: 0.904109589041096
#
# ->-> Total training time: 0 minutes 5 seconds

# %%
#Feature importance for lgb
fold_importance_df
# Out:
#                    feature  importance
# 0           Freq_Of_Word_1          35
# 1           Freq_Of_Word_2         133
# 2           Freq_Of_Word_3         426
# 3           Freq_Of_Word_4           0
# 4           Freq_Of_Word_5         395
# 5           Freq_Of_Word_6          66
# 6           Freq_Of_Word_7         340
# 7           Freq_Of_Word_8         150
# 8           Freq_Of_Word_9          96
# 9          Freq_Of_Word_10         154
# 10         Freq_Of_Word_11          38
# 11         Freq_Of_Word_12         684
# 12         Freq_Of_Word_13          88
# 13         Freq_Of_Word_14          19
# 14         Freq_Of_Word_15           0
# 15         Freq_Of_Word_16         411
# 16         Freq_Of_Word_17         175
# 17         Freq_Of_Word_18         236
# 18         Freq_Of_Word_19        1066
# 19         Freq_Of_Word_20         146
# 20         Freq_Of_Word_21         868
# 21         Freq_Of_Word_22           0
# 22         Freq_Of_Word_23         189
# 23         Freq_Of_Word_24         137
# 24         Freq_Of_Word_25         565
# 25         Freq_Of_Word_26          29
# 26         Freq_Of_Word_27         448
# 27         Freq_Of_Word_28         117
# 28         Freq_Of_Word_29          73
# 29         Freq_Of_Word_30           1
# 30         Freq_Of_Word_31           0
# 31         Freq_Of_Word_32           0
# 32         Freq_Of_Word_33          42
# 33         Freq_Of_Word_34           0
# 34         Freq_Of_Word_35           8
# 35         Freq_Of_Word_36          95
# 36         Freq_Of_Word_37         192
# 37         Freq_Of_Word_38           0
# 38         Freq_Of_Word_39           5
# 39         Freq_Of_Word_40           3
# 40         Freq_Of_Word_41           0
# 41         Freq_Of_Word_42          68
# 42         Freq_Of_Word_43           0
# 43         Freq_Of_Word_44           6
# 44         Freq_Of_Word_45         435
# 45         Freq_Of_Word_46         362
# 46         Freq_Of_Word_47           0
# 47         Freq_Of_Word_48           0
# 48         Freq_Of_Word_49         196
# 49         Freq_Of_Word_50         627
# 50    TotalEmojiCharacters         412
# 51  LengthOFFirstParagraph        1230
# 52         StylizedLetters        1201

# %%
#Selecting Features with high feature importance
df1=train_df[['Freq_Of_Word_1', 'Freq_Of_Word_2', 'Freq_Of_Word_3', 
       'Freq_Of_Word_5', 'Freq_Of_Word_6', 'Freq_Of_Word_7', 'Freq_Of_Word_8',
       'Freq_Of_Word_9', 'Freq_Of_Word_10', 'Freq_Of_Word_11',
       'Freq_Of_Word_12', 'Freq_Of_Word_13', 'Freq_Of_Word_14',
       'Freq_Of_Word_16', 'Freq_Of_Word_17',
       'Freq_Of_Word_18', 'Freq_Of_Word_19', 'Freq_Of_Word_20',
       'Freq_Of_Word_21', 'Freq_Of_Word_22', 'Freq_Of_Word_23',
       'Freq_Of_Word_24', 'Freq_Of_Word_25', 'Freq_Of_Word_26',
       'Freq_Of_Word_27', 'Freq_Of_Word_28', 'Freq_Of_Word_29',
       'Freq_Of_Word_30', 
       'Freq_Of_Word_33', 'Freq_Of_Word_36', 'Freq_Of_Word_37',
       'Freq_Of_Word_42', 'Freq_Of_Word_44',
       'Freq_Of_Word_45', 'Freq_Of_Word_46','Freq_Of_Word_49', 'Freq_Of_Word_50',
       'TotalEmojiCharacters', 'LengthOFFirstParagraph', 'StylizedLetters',
       'IsGoodNews']]
df1
# Out:
#      Freq_Of_Word_1  Freq_Of_Word_2  Freq_Of_Word_3  Freq_Of_Word_5  \
# 0             -0.35            2.62            1.25           -0.47
# 1             -0.35           -0.32           -0.56           -0.47
# 2             -0.35           -0.32           -0.56           -0.47
# 3              1.21            2.68            1.29            0.22
# 4             -0.35           -0.32           -0.56           -0.47
# ..              ...             ...             ...             ...
# 942           -0.25           -0.29           -0.28           -0.34
# 943           -0.35           -0.32           -0.56            0.36
# 944           -0.19           -0.16            0.20            0.02
# 945           -0.35           -0.32            0.41           -0.47
# 946           -0.35           -0.32           -0.56            0.29
#
#      Freq_Of_Word_6  Freq_Of_Word_7  Freq_Of_Word_8  Freq_Of_Word_9  \
# 0             -0.35           -0.30           -0.24           -0.32
# 1             -0.35           -0.30            3.84           -0.32
# 2             -0.35           -0.30           -0.24           -0.32
# 3             -0.35           -0.30            0.86           -0.32
# 4             -0.35           -0.30           -0.24           -0.32
# ..              ...             ...             ...             ...
# 942           -0.25           -0.30           -0.17           -0.21
# 943           -0.35           -0.30           -0.24           -0.32
# 944           -0.35           -0.30           -0.24            1.76
# 945            1.41           -0.30           -0.24           -0.32
# 946           -0.35           -0.30           -0.24           -0.32
#
#      Freq_Of_Word_10  Freq_Of_Word_11  Freq_Of_Word_12  Freq_Of_Word_13  \
# 0              -0.35            -0.32            -0.64            -0.31
# 1              -0.35            -0.32            -0.64            -0.31
# 2              -0.35            -0.32            -0.64            -0.31
# 3               2.37            -0.32             2.03            -0.31
# 4              -0.35            -0.32            -0.64            -0.31
# ..               ...              ...              ...              ...
# 942            -0.20            -0.32            -0.36             0.01
# 943            -0.35            -0.32            -0.64            -0.31
# 944            -0.28            -0.32            -0.33             0.01
# 945            -0.35            -0.32            -0.64             1.15
# 946            -0.35            -0.32            -0.05             1.20
#
#      Freq_Of_Word_14  Freq_Of_Word_16  Freq_Of_Word_17  Freq_Of_Word_18  \
# 0              -0.18            -0.33            -0.32            -0.36
# 1              -0.18            -0.33            -0.32            -0.36
# 2              -0.18            -0.33            -0.32            -0.36
# 3               1.29             0.29            -0.32            -0.36
# 4              -0.18            -0.33            -0.32            -0.36
# ..               ...              ...              ...              ...
# 942            -0.03            -0.29            -0.21            -0.30
# 943            -0.18            -0.33            -0.32            -0.36
# 944            -0.18            -0.11            -0.32            -0.36
# 945            -0.18             0.33            -0.32            -0.36
# 946            -0.18            -0.33            -0.32            -0.36
#
#      Freq_Of_Word_19  Freq_Of_Word_20  Freq_Of_Word_21  Freq_Of_Word_22  \
# 0              -0.71             1.07             0.95            -0.13
# 1              -0.97            -0.19            -0.71            -0.13
# 2              -0.97            -0.19            -0.71            -0.13
# 3               0.13            -0.19             3.98            -0.13
# 4              -0.97            -0.19            -0.71            -0.13
# ..               ...              ...              ...              ...
# 942            -0.90            -0.19            -0.58            -0.13
# 943            -0.48            -0.19            -0.45            -0.13
# 944            -0.39            -0.06             0.10            -0.13
# 945            -0.39            -0.19            -0.71            -0.13
# 946            -0.67            -0.19             0.22            -0.13
#
#      Freq_Of_Word_23  Freq_Of_Word_24  Freq_Of_Word_25  Freq_Of_Word_26  \
# 0              -0.29             0.76            -0.33            -0.30
# 1              -0.29            -0.20            -0.33            -0.30
# 2              -0.29            -0.20            -0.33            -0.30
# 3              -0.29            -0.20            -0.33            -0.30
# 4              -0.29            -0.20            -0.33            -0.30
# ..               ...              ...              ...              ...
# 942            -0.10            -0.20            -0.33            -0.30
# 943            -0.29            -0.20            -0.17             0.03
# 944            -0.29            -0.10            -0.33            -0.30
# 945            -0.29            -0.20            -0.33            -0.30
# 946            -0.29            -0.20            -0.33            -0.30
#
#      Freq_Of_Word_27  Freq_Of_Word_28  Freq_Of_Word_29  Freq_Of_Word_30  \
# 0              -0.21            -0.23            -0.16            -0.23
# 1              -0.21            -0.23            -0.16            -0.23
# 2              -0.21            -0.23            -0.16            -0.23
# 3              -0.21            -0.23            -0.16            -0.23
# 4               0.10            -0.23             0.64            -0.23
# ..               ...              ...              ...              ...
# 942            -0.21            -0.23            -0.16            -0.23
# 943            -0.04             0.95            -0.16            -0.23
# 944            -0.21            -0.23            -0.09            -0.23
# 945            -0.21            -0.23            -0.16            -0.23
# 946             0.40            -0.23            -0.16            -0.23
#
#      Freq_Of_Word_33  Freq_Of_Word_36  Freq_Of_Word_37  Freq_Of_Word_42  \
# 0              -0.18            -0.24            -0.33            -0.17
# 1              -0.18            -0.24             3.68            -0.17
# 2              -0.18            -0.24            -0.33            -0.17
# 3              -0.18            -0.24            -0.33            -0.17
# 4              -0.18            -0.24            -0.33            -0.17
# ..               ...              ...              ...              ...
# 942             3.51             0.02             1.72            -0.16
# 943            -0.18            -0.24            -0.33            -0.17
# 944            -0.18            -0.24            -0.33            -0.04
# 945            -0.18            -0.24            -0.33            -0.17
# 946            -0.18            -0.24            -0.33            -0.17
#
#      Freq_Of_Word_44  Freq_Of_Word_45  Freq_Of_Word_46  Freq_Of_Word_49  \
# 0              -0.12            -0.32            -0.21             0.08
# 1              -0.12            -0.32            -0.21            -0.15
# 2              -0.12            -0.32            -0.21            -0.15
# 3              -0.12            -0.32            -0.21            -0.15
# 4              -0.12            -0.32            -0.21            -0.15
# ..               ...              ...              ...              ...
# 942            -0.08            -0.32            -0.10            -0.02
# 943            -0.12            -0.32            -0.21            -0.15
# 944            -0.12            -0.28            -0.21            -0.09
# 945            -0.12            -0.32            -0.21            -0.15
# 946            -0.12             0.17            -0.21            -0.15
#
#      Freq_Of_Word_50  TotalEmojiCharacters  LengthOFFirstParagraph  \
# 0               0.16                 -0.03                   -0.05
# 1              -0.45                 -0.11                   -0.20
# 2              -0.45                 -0.11                   -0.19
# 3               0.34                  1.33                    2.27
# 4               0.93                 -0.03                   -0.11
# ..               ...                   ...                     ...
# 942             0.13                 -0.08                    0.20
# 943             0.22                  0.21                    1.15
# 944            -0.15                 -0.03                    0.15
# 945            -0.45                 -0.11                   -0.20
# 946             0.12                 -0.11                   -0.21
#
#      StylizedLetters  IsGoodNews
# 0               0.22           1
# 1              -0.41           0
# 2              -0.39           0
# 3               0.60           1
# 4              -0.13           0
# ..               ...         ...
# 942             4.02           0
# 943             0.18           0
# 944             1.41           1
# 945            -0.37           0
# 946            -0.37           0
#
# [947 rows x 41 columns]

# %%
#Training Lgbm with good feature importance
train, test = df1,test_df[['Freq_Of_Word_1', 'Freq_Of_Word_2', 'Freq_Of_Word_3', 
       'Freq_Of_Word_5', 'Freq_Of_Word_6', 'Freq_Of_Word_7', 'Freq_Of_Word_8',
       'Freq_Of_Word_9', 'Freq_Of_Word_10', 'Freq_Of_Word_11',
       'Freq_Of_Word_12', 'Freq_Of_Word_13', 'Freq_Of_Word_14',
       'Freq_Of_Word_16', 'Freq_Of_Word_17',
       'Freq_Of_Word_18', 'Freq_Of_Word_19', 'Freq_Of_Word_20',
       'Freq_Of_Word_21', 'Freq_Of_Word_22', 'Freq_Of_Word_23',
       'Freq_Of_Word_24', 'Freq_Of_Word_25', 'Freq_Of_Word_26',
       'Freq_Of_Word_27', 'Freq_Of_Word_28', 'Freq_Of_Word_29',
       'Freq_Of_Word_30', 
       'Freq_Of_Word_33', 'Freq_Of_Word_36', 'Freq_Of_Word_37',
       'Freq_Of_Word_42', 'Freq_Of_Word_44',
       'Freq_Of_Word_45', 'Freq_Of_Word_46','Freq_Of_Word_49', 'Freq_Of_Word_50',
       'TotalEmojiCharacters', 'LengthOFFirstParagraph', 'StylizedLetters']]
target = df1['IsGoodNews']
features = [c for c in train.columns if c not in ['IsGoodNews']]

# %%
#Function to perform training of lgb with cross validation
import datetime
import time
from sklearn.model_selection import *
from sklearn.metrics import *
def custom_metric(y_true, y_pred):
    return f'F1_score: {f1_score(y_true, np.round(y_pred))}'
N_FOLDS = 5

training_start_time = time.time()

max_iter = N_FOLDS
folds = StratifiedKFold(n_splits = max_iter)
oofs = np.zeros(len(train))
preds_test = np.zeros(len(test))

feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(train, target.values)):
    
    print(f'\n---- Fold {fold_} -----\n')
    
    fold_start_time = time.time()
    
    X_trn, y_trn = train.iloc[trn_idx][features], target.iloc[trn_idx]
    X_val, y_val = train.iloc[val_idx][features], target.iloc[val_idx]
    X_test = test[features]
    
    print(X_trn.shape)
    
    clf_1 = LGBMClassifier(n_estimators = 4000, learning_rate = 0.01, num_leaves=200, colsample_by_tree =3, reg_alpha=0.5, reg_lambda=0.5, 
                        bagging_freq=1, bagging_fraction=0.8, max_bin=50,random_state=9)
    _ = clf_1.fit(X_trn, y_trn, eval_set = [(X_trn, y_trn), (X_val, y_val)], eval_metric = 'f1', verbose = 100, early_stopping_rounds = 200)
    
    oofs[val_idx] = clf_1.predict_proba(X_val)[:, 1]
    current_test_pred = clf_1.predict_proba(X_test)[:, 1]
    preds_test += clf_1.predict_proba(X_test)[:, 1]/max_iter
    
    print(f'\n Fold {custom_metric(y_val, oofs[val_idx])}')

    #fold_importance_df = pd.DataFrame({'feature': X_trn.columns.tolist(), 'importance': clf.feature_importances_})
    #feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    fold_end_time = time.time()
    total_fold_time = int(fold_end_time - fold_start_time)
    
    print(f"\n->-> Fold ran for {(total_fold_time)//60} minutes {(total_fold_time)%60} seconds")
    

print(f'\nOOF val score: {custom_metric(target, oofs)}')
training_end_time = time.time()
total_training_time = int(training_end_time - training_start_time)

print(f'\n->-> Total training time: {(total_training_time)//60} minutes {(total_training_time)%60} seconds')
# Out:
# ---- Fold 0 -----
#
# (757, 40)
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.34926	valid_1's binary_logloss: 0.370118
# [200]	training's binary_logloss: 0.225559	valid_1's binary_logloss: 0.257285
# [300]	training's binary_logloss: 0.164053	valid_1's binary_logloss: 0.209273
# [400]	training's binary_logloss: 0.127554	valid_1's binary_logloss: 0.188457
# [500]	training's binary_logloss: 0.103603	valid_1's binary_logloss: 0.178185
# [600]	training's binary_logloss: 0.086663	valid_1's binary_logloss: 0.173196
# [700]	training's binary_logloss: 0.0743391	valid_1's binary_logloss: 0.170642
# [800]	training's binary_logloss: 0.0650923	valid_1's binary_logloss: 0.169049
# [900]	training's binary_logloss: 0.0581935	valid_1's binary_logloss: 0.169704
# Early stopping, best iteration is:
# [797]	training's binary_logloss: 0.0653434	valid_1's binary_logloss: 0.168908
#
#  Fold F1_score: 0.8918918918918919
#
# ->-> Fold ran for 0 minutes 0 seconds
#
# ---- Fold 1 -----
#
# (757, 40)
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.349403	valid_1's binary_logloss: 0.377078
# [200]	training's binary_logloss: 0.22462	valid_1's binary_logloss: 0.272774
# [300]	training's binary_logloss: 0.162555	valid_1's binary_logloss: 0.227166
# [400]	training's binary_logloss: 0.125354	valid_1's binary_logloss: 0.20584
# [500]	training's binary_logloss: 0.101557	valid_1's binary_logloss: 0.192623
# [600]	training's binary_logloss: 0.0849518	valid_1's binary_logloss: 0.186003
# [700]	training's binary_logloss: 0.0731162	valid_1's binary_logloss: 0.180931
# [800]	training's binary_logloss: 0.064064	valid_1's binary_logloss: 0.176357
# [900]	training's binary_logloss: 0.057404	valid_1's binary_logloss: 0.174286
# [1000]	training's binary_logloss: 0.0519551	valid_1's binary_logloss: 0.172663
# [1100]	training's binary_logloss: 0.0477103	valid_1's binary_logloss: 0.171973
# [1200]	training's binary_logloss: 0.0442994	valid_1's binary_logloss: 0.171902
# [1300]	training's binary_logloss: 0.0414487	valid_1's binary_logloss: 0.171806
# Early stopping, best iteration is:
# [1147]	training's binary_logloss: 0.045968	valid_1's binary_logloss: 0.171493
#
#  Fold F1_score: 0.9115646258503401
#
# ->-> Fold ran for 0 minutes 1 seconds
#
# ---- Fold 2 -----
#
# (758, 40)
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.349208	valid_1's binary_logloss: 0.374141
# [200]	training's binary_logloss: 0.226307	valid_1's binary_logloss: 0.257869
# [300]	training's binary_logloss: 0.165324	valid_1's binary_logloss: 0.208894
# [400]	training's binary_logloss: 0.128074	valid_1's binary_logloss: 0.183734
# [500]	training's binary_logloss: 0.103216	valid_1's binary_logloss: 0.170014
# [600]	training's binary_logloss: 0.0858327	valid_1's binary_logloss: 0.164989
# [700]	training's binary_logloss: 0.0732651	valid_1's binary_logloss: 0.160047
# [800]	training's binary_logloss: 0.0638822	valid_1's binary_logloss: 0.15828
# [900]	training's binary_logloss: 0.0568142	valid_1's binary_logloss: 0.15666
# [1000]	training's binary_logloss: 0.0513326	valid_1's binary_logloss: 0.156666
# [1100]	training's binary_logloss: 0.0468588	valid_1's binary_logloss: 0.155233
# [1200]	training's binary_logloss: 0.0432078	valid_1's binary_logloss: 0.157194
# [1300]	training's binary_logloss: 0.0402707	valid_1's binary_logloss: 0.157503
# Early stopping, best iteration is:
# [1108]	training's binary_logloss: 0.0465676	valid_1's binary_logloss: 0.155213
#
#  Fold F1_score: 0.921985815602837
#
# ->-> Fold ran for 0 minutes 1 seconds
#
# ---- Fold 3 -----
#
# (758, 40)
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.347153	valid_1's binary_logloss: 0.381294
# [200]	training's binary_logloss: 0.221634	valid_1's binary_logloss: 0.280407
# [300]	training's binary_logloss: 0.159383	valid_1's binary_logloss: 0.239827
# [400]	training's binary_logloss: 0.121949	valid_1's binary_logloss: 0.222351
# [500]	training's binary_logloss: 0.097655	valid_1's binary_logloss: 0.2111
# [600]	training's binary_logloss: 0.0806849	valid_1's binary_logloss: 0.20175
# [700]	training's binary_logloss: 0.0685837	valid_1's binary_logloss: 0.196953
# [800]	training's binary_logloss: 0.0597058	valid_1's binary_logloss: 0.19275
# [900]	training's binary_logloss: 0.0527088	valid_1's binary_logloss: 0.190072
# [1000]	training's binary_logloss: 0.0473021	valid_1's binary_logloss: 0.18866
# [1100]	training's binary_logloss: 0.0431815	valid_1's binary_logloss: 0.188898
# [1200]	training's binary_logloss: 0.0398103	valid_1's binary_logloss: 0.187505
# [1300]	training's binary_logloss: 0.0370731	valid_1's binary_logloss: 0.186628
# [1400]	training's binary_logloss: 0.0347884	valid_1's binary_logloss: 0.18625
# [1500]	training's binary_logloss: 0.0328287	valid_1's binary_logloss: 0.186994
# Early stopping, best iteration is:
# [1380]	training's binary_logloss: 0.0352203	valid_1's binary_logloss: 0.186112
#
#  Fold F1_score: 0.9090909090909091
#
# ->-> Fold ran for 0 minutes 1 seconds
#
# ---- Fold 4 -----
#
# (758, 40)
# Training until validation scores don't improve for 200 rounds.
# [100]	training's binary_logloss: 0.348474	valid_1's binary_logloss: 0.374061
# [200]	training's binary_logloss: 0.223583	valid_1's binary_logloss: 0.274126
# [300]	training's binary_logloss: 0.159717	valid_1's binary_logloss: 0.23544
# [400]	training's binary_logloss: 0.12257	valid_1's binary_logloss: 0.219128
# [500]	training's binary_logloss: 0.0979849	valid_1's binary_logloss: 0.212582
# [600]	training's binary_logloss: 0.081083	valid_1's binary_logloss: 0.206856
# [700]	training's binary_logloss: 0.0687906	valid_1's binary_logloss: 0.205703
# [800]	training's binary_logloss: 0.0598635	valid_1's binary_logloss: 0.20435
# [900]	training's binary_logloss: 0.052944	valid_1's binary_logloss: 0.202491
# [1000]	training's binary_logloss: 0.0475492	valid_1's binary_logloss: 0.20305
# [1100]	training's binary_logloss: 0.0433131	valid_1's binary_logloss: 0.203932
# Early stopping, best iteration is:
# [922]	training's binary_logloss: 0.051667	valid_1's binary_logloss: 0.201731
#
#  Fold F1_score: 0.8933333333333333
#
# ->-> Fold ran for 0 minutes 0 seconds
#
# OOF val score: F1_score: 0.9053497942386831
#
# ->-> Total training time: 0 minutes 4 seconds

# %%
#Applying Logistic Regression
train, test = train_df,test_df
target = train_df['IsGoodNews']
features = [c for c in train.columns if c not in ['IsGoodNews']]

# %%
import datetime
import time
from sklearn.model_selection import *
from sklearn.metrics import *
def custom_metric(y_true, y_pred):
    return f'F1_score: {f1_score(y_true, np.round(y_pred))}'
N_FOLDS = 5

training_start_time = time.time()

max_iter = N_FOLDS
folds = StratifiedKFold(n_splits = max_iter)
oofs = np.zeros(len(train))
preds_test = np.zeros(len(test))

feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(train, target.values)):
    
    print(f'\n---- Fold {fold_} -----\n')
    
    fold_start_time = time.time()
    
    X_trn, y_trn = train.iloc[trn_idx][features], target.iloc[trn_idx]
    X_val, y_val = train.iloc[val_idx][features], target.iloc[val_idx]
    X_test = test[features]
    
    print(X_trn.shape)
    
    clf_2 = LogisticRegression(random_state=9)
    _ = clf_2.fit(X_trn, y_trn) 
    
    oofs[val_idx] = clf_2.predict_proba(X_val)[:, 1]
    current_test_pred = clf_2.predict_proba(X_test)[:, 1]
    preds_test += clf_2.predict_proba(X_test)[:, 1]/max_iter
    
    print(f'\n Fold {custom_metric(y_val, oofs[val_idx])}')

    #fold_importance_df = pd.DataFrame({'feature': X_trn.columns.tolist(), 'importance': clf.feature_importances_})
    #feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    fold_end_time = time.time()
    total_fold_time = int(fold_end_time - fold_start_time)
    
    print(f"\n->-> Fold ran for {(total_fold_time)//60} minutes {(total_fold_time)%60} seconds")
    

print(f'\nOOF val score: {custom_metric(target, oofs)}')
training_end_time = time.time()
total_training_time = int(training_end_time - training_start_time)

print(f'\n->-> Total training time: {(total_training_time)//60} minutes {(total_training_time)%60} seconds')
# Out:
# ---- Fold 0 -----
#
# (757, 53)
#
#  Fold F1_score: 0.9078947368421053
#
# ->-> Fold ran for 0 minutes 0 seconds
#
# ---- Fold 1 -----
#
# (757, 53)
#
#  Fold F1_score: 0.875
#
# ->-> Fold ran for 0 minutes 0 seconds
#
# ---- Fold 2 -----
#
# (758, 53)
#
#  Fold F1_score: 0.8695652173913043
#
# ->-> Fold ran for 0 minutes 0 seconds
#
# ---- Fold 3 -----
#
# (758, 53)
#
#  Fold F1_score: 0.8759124087591241
#
# ->-> Fold ran for 0 minutes 0 seconds
#
# ---- Fold 4 -----
#
# (758, 53)
#
#  Fold F1_score: 0.8873239436619719
#
# ->-> Fold ran for 0 minutes 0 seconds
#
# OOF val score: F1_score: 0.8835904628330996
#
# ->-> Total training time: 0 minutes 0 seconds

# %%
#Applying voting classifier
train, test = train_df,test_df
target = train_df['IsGoodNews']
features = [c for c in train.columns if c not in ['IsGoodNews']]

# %%
import datetime
import time
from sklearn.model_selection import *
from sklearn.metrics import *
def custom_metric(y_true, y_pred):
    return f'F1_score: {f1_score(y_true, np.round(y_pred))}'
N_FOLDS = 5

training_start_time = time.time()

max_iter = N_FOLDS
folds = StratifiedKFold(n_splits = max_iter)
oofs = np.zeros(len(train))
preds_test = np.zeros(len(test))

feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(train, target.values)):
    
    print(f'\n---- Fold {fold_} -----\n')
    
    fold_start_time = time.time()
    
    X_trn, y_trn = train.iloc[trn_idx][features], target.iloc[trn_idx]
    X_val, y_val = train.iloc[val_idx][features], target.iloc[val_idx]
    X_test = test[features]
    
    print(X_trn.shape)
    
    clf_vote = VotingClassifier(estimators =[('log',clf_2),('lgb',clf_1)], voting = 'soft')
    _ = clf_vote.fit(X_trn, y_trn) 
    
    oofs[val_idx] = clf_vote.predict_proba(X_val)[:, 1]
    current_test_pred = clf_vote.predict_proba(X_test)[:, 1]
    preds_test += clf_vote.predict_proba(X_test)[:, 1]/max_iter
    
    print(f'\n Fold {custom_metric(y_val, oofs[val_idx])}')

    #fold_importance_df = pd.DataFrame({'feature': X_trn.columns.tolist(), 'importance': clf.feature_importances_})
    #feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    fold_end_time = time.time()
    total_fold_time = int(fold_end_time - fold_start_time)
    
    print(f"\n->-> Fold ran for {(total_fold_time)//60} minutes {(total_fold_time)%60} seconds")
    

print(f'\nOOF val score: {custom_metric(target, oofs)}')
training_end_time = time.time()
total_training_time = int(training_end_time - training_start_time)

print(f'\n->-> Total training time: {(total_training_time)//60} minutes {(total_training_time)%60} seconds')
# Out:
# ---- Fold 0 -----
#
# (757, 53)
#
#  Fold F1_score: 0.9150326797385621
#
# ->-> Fold ran for 0 minutes 2 seconds
#
# ---- Fold 1 -----
#
# (757, 53)
#
#  Fold F1_score: 0.9103448275862069
#
# ->-> Fold ran for 0 minutes 2 seconds
#
# ---- Fold 2 -----
#
# (758, 53)
#
#  Fold F1_score: 0.9444444444444445
#
# ->-> Fold ran for 0 minutes 1 seconds
#
# ---- Fold 3 -----
#
# (758, 53)
#
#  Fold F1_score: 0.9090909090909091
#
# ->-> Fold ran for 0 minutes 1 seconds
#
# ---- Fold 4 -----
#
# (758, 53)
#
#  Fold F1_score: 0.9115646258503401
#
# ->-> Fold ran for 0 minutes 2 seconds
#
# OOF val score: F1_score: 0.9180327868852459
#
# ->-> Total training time: 0 minutes 10 seconds

# %%
test_df['IsGoodNews']=clf_vote.predict(test_df)

# %%
A=test_df['IsGoodNews']
A=pd.DataFrame(A)
A
A.to_excel('lgb_log_model_1.xlsx')
# Out:
#      IsGoodNews
# 0             1
# 1             0
# 2             0
# 3             1
# 4             0
# ..          ...
# 522           0
# 523           1
# 524           0
# 525           0
# 526           0
#
# [527 rows x 1 columns]

# %%
from google.colab import files
files.download('lgb_log_model_1.xlsx')
